# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import seaborn as sns
import math
from collections import OrderedDict
from collections import Counter

# %%
# checking to make sure our virtual environment is running correctly 

print(pd.__version__)
# Out:
# 2.1.0

# %%
df = pd.read_csv('healthcare.csv')

# %%
df.head(10)
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
# 5   6            5      116             74              0        0  25.6
# 6   7            3       78             50             32       88  31.0
# 7   8           10      115              0              0        0  35.3
# 8   9            2      197             70             45      543  30.5
# 9  10            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %% [markdown]
# ## Peforming baseline EDA

# %% [markdown]
# ### 1. Checking for missing data
#
# - Based on the code below, the data seems like it's not missing anything. Cleaning seems unnecessary

# %%
df.isna().sum()

# data seems pretty good to use
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### 2. Distribution of the data

# %%
df.dtypes
# Out:
# Id                            int64
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #### List comprehension to filter out discrete feature columns
#
# Check if data type for each feature is equal to integer

# %%
df1 = df.drop(columns=['Id', 'Outcome'])


discrete_features=[column_name for column_name in df1.columns if pd.api.types.is_integer_dtype(df1[column_name]) and column_name != 'Pregnancies']



#for feature in discrete_features:
    #sns.histplot(df1[feature], bins=10, kde=True, color='blue')
    

#fig, axs = plt.subplots(ncols=len(discrete_features))

#for index, feature in enumerate(discrete_features):
    #sns.histplot(df1[feature], bins=10, color='blue', ax=axs[index])
    


plt.figure(figsize=(12, 12))
for index, feature in enumerate(discrete_features):
    plt.subplot(4, 2, index + 1)
    sns.histplot(df1[feature], bins=10, kde=True, color='blue')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(f'{feature}')


plt.tight_layout()
plt.show()

#plt.figure(figsize=(8, 6))
#sns.histplot(df['Age'], bins=10, kde=True, color='blue')
# Out:
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 3. Checking for multicolinearity and colinearity
#
#
# From this correlation matrix, we can see that glucose and outcome has a positive correlation, which means that an increase
# in the amount of glucose correlates with a greater likelihood of the presence of diabetes

# %%
# visualizating correlation matrix to see if there are any correlations between features

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr() , annot = True , cmap = "YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Which features are good predictors for Outcome in our dataset?

# %%
plt.figure(figsize=(8, 6))


plt.xlabel('Diabetes (0: No, 1: Yes)')
plt.ylabel('Glucose Concentration')
plt.title('Boxplot of Glucose Concentration by Diabetes Status')
sns.boxplot(x='Outcome', y='Glucose', data=df)
# Out:
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shinjiyamashita/Desktop/ml-journey/ml-models/ml-venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: title={'center': 'Boxplot of Glucose Concentration by Diabetes Status'}, xlabel='Outcome', ylabel='Glucose'>

# %%
# check for imbalanced dataset


print(df["Outcome"].value_counts())


df.groupby('Outcome').size().plot(
    kind='pie',
    y="Outcome",
    label="Type",
    autopct='%1.1f%%'
)
# Out:
# Outcome
# 0    1816
# 1     952
# Name: count, dtype: int64
# <Axes: ylabel='Type'>

# %%
X = df.drop(columns=['Id', 'Outcome'])

# %%
X.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y = df['Outcome']
y.head(5)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# perform a training test split 
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
print(y_test.shape)
print(X_train.shape)
c, b = X.shape
print(c)
print(b)
# Out:
# (692,)
# (2076, 8)
# 2768
# 8

# %% [markdown]
# # Implementing Logistic Regression from scratch

# %% [markdown]
# ### First step: Sigmoid Function
#
# In this function, we are first coding the sigmoid function so once we compute our z value which consists of a dot product of our input features and weight parameters and bias. This computes a value between 0 and 1 which is necessary for binary logistic classification.

# %%
# create the sigmoid activation function for logistic regression (return output of 0 or 1)

def sigmoid(x):
    
    g = 1 / (1 + np.exp(-x))
    
    
    return g

# %%
print(sigmoid(0))
# Out:
# 0.5

# %% [markdown]
# ### Second step: Cost Function
#
# We code the cost function which in this case is the binarycross entropy cost function which is different from MSE which we use for linear regression. We compute the cost function, so we know that it is decreasing after each iteration

# %%
def cost_one(actual, out):
    cost = actual*np.log(out)+(1-actual)*np.log(1-out)
    
    return cost

# %% [markdown]
# ### Third step: Gradient Descent for one iteration

# %%
# implement gradient descent one iteration


def gradient_descent(X, y, w, b, sig, cost_one):
    
    m, n = X.shape
    dj_dw = np.zeros(n)
    dj_db = 0
    total_cost = 0
    
    for i in range(m):
        out = np.dot(X[i], w) + b
        apply_sig = sig(out) - y[i]
        total_cost += cost_one(y[i], sig(out))
        for j in range(n):
            dj_dw[j] += apply_sig * X[i][j] # access two dimensional arrays
        dj_db += apply_sig
        
        
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    total_cost = total_cost / -m
            
    return dj_dw, dj_db, total_cost # return the partial derivatives of both

# %% [markdown]
# ### Last step: Updating our parameters

# %%
# run multiple iterations
            
            
w = np.zeros(X.shape[1])
b = 0
total_cost = 0


X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
  
    

def full_gradient(X, y, w_in, b_in, grad_desc, sig, lr, epochs, cost_one):
    
    costs = []
    
    for i in range(epochs):
        dj_dw, dj_db, curr_cost = grad_desc(X, y, w_in, b_in, sig, cost_one)
        w_in = w_in - lr * dj_dw
        b_in = b_in - lr * dj_db
        if (i % 10 == 0):
            costs.append(curr_cost)
        
    return w_in, b_in, costs # return final parameters after running gradient descent multiple times

# %%
final_w, final_b, costs = full_gradient(X_train, y_train, w, b, gradient_descent, sigmoid, 0.001, 1000, cost_one)

# %%
print(final_w)
print(final_b)
print(costs)
# Out:
# [ 0.14894626  0.00161686 -0.11542505 -0.00639137 -0.02978325 -0.01499787
#   0.00412701 -0.0148024 ]
# -0.03793101565385052
# [0.6931471805599105, 4.6096493928547515, 2.4877951192002117, 1.0229764857677164, 0.8763079633259598, 0.8378904589273266, 4.331313773247607, 0.9134534842455231, 4.14600524335113, 1.5780452712801605, 3.9849707724284005, 2.081427839557552, 4.166994783587658, 1.3389980661725323, 3.954791196158665, 1.976084264772146, 4.106194627431345, 1.4326089447533092, 3.9545489780550467, 1.8980845564506184, 4.071645867179306, 1.4908782582920017, 3.9588979496214187, 1.8450689316380608, 4.050936537097993, 1.5287915517570079, 3.9633902746577476, 1.8080639965070888, 4.037188308916263, 1.5557526620556685, 3.967263290617531, 1.7803535170645715, 4.026973401066719, 1.5769192052005607, 3.9705844897717752, 1.7580345512397504, 4.018656578741759, 1.5948527737296148, 3.973494709165639, 1.7391077231301606, 4.011494930825611, 1.610640978609285, 3.9760459190188753, 1.7227144398958187, 4.005189603780024, 1.6245705458133688, 3.978200447956225, 1.7086308517687583, 3.999654878315822, 1.636549218822253, 3.979874362518844, 1.6969144869619166, 3.9948846518691243, 1.6463989644493735, 3.980990256928103, 1.6876432550812202, 3.9908700435148243, 1.6540531761476995, 3.9815192623334026, 1.6807513827037013, 3.9875578583173845, 1.6596451628344278, 3.981497138008797, 1.6759813914971513, 3.9848461012558727, 1.6634893125675945, 3.981012408666693, 1.6729350214857854, 3.982604236987734, 1.6659955522734804, 3.9801786681873454, 1.671168609397076, 3.98070032347645, 1.6675740322990953, 3.979107094008482, 1.670277879448973, 3.979021450274837, 1.6685693423880712, 3.9778890324268295, 1.669944762805325, 3.97748277915491, 1.6692344814720474, 3.97659013842066, 1.6699467641383705, 3.9760271341041697, 1.6697351429532357, 3.9752525841967166, 1.6701429441487234, 3.974619484606825, 1.6701690999144805, 3.973900860153395, 1.6704513527598, 3.9732401340444814, 1.6705884294259898, 3.9725478946170965, 1.6708276612009487, 3.971878837133595, 1.6710179327844805, 3.9711998919698863, 1.67124914540722]

# %% [markdown]
# ### Cost function analysis
#
# It seems to be oscillating, maybe we can try feature scaling?

# %%
plt.plot(list(range(100)), costs)

# %% [markdown]
# ### Feature scaling
#
# Here we apply the standard scale which standardizes our data. This means that our mean is centered around zero and
# Our cost function seems to be decreasing with each iteration

# %%
scaler = StandardScaler()
X_train_standardized = scaler.fit_transform(X_train)


final_w, final_b, costs_1 = full_gradient(X_train_standardized, y_train, w, b, gradient_descent, sigmoid, 0.01, 1000, cost_one)

# %%
plt.plot(list(range(100)), costs_1)

# %%
print(costs_1)
# Out:
# [0.6931471805599105, 0.6811414539126726, 0.6700420199563538, 0.6597706897221053, 0.6502552456199915, 0.6414293822493694, 0.6332325111204067, 0.6256094723847091, 0.6185101889290676, 0.611889290437209, 0.6057057280041246, 0.5999223939435006, 0.5945057566461421, 0.589425516656589, 0.5846542873897904, 0.5801673019387427, 0.575942146061457, 0.57195851653515, 0.5681980035062121, 0.5646438951500018, 0.561281002811099, 0.558095504767125, 0.555074806806877, 0.5522074179076496, 0.5494828394167882, 0.5468914662746392, 0.5444244989511187, 0.5420738648999209, 0.5398321484593153, 0.5376925282446706, 0.5356487211841213, 0.533694932445102, 0.5318258105860892, 0.5300364073450634, 0.5283221415450485, 0.5266787666578923, 0.5251023416212715, 0.5235892045513137, 0.5221359490351112, 0.5207394027240415, 0.519396607981284, 0.5181048043652386, 0.5168614127557, 0.5156640209514429, 0.5145103705874594, 0.5133983452368801, 0.5123259595777901, 0.511291349518288, 0.5102927631848333, 0.5093285526891684, 0.5083971665982961, 0.5074971430399444, 0.5066271033831128, 0.5057857464396668, 0.504971843138393, 0.5041842316281038, 0.5034218127706115, 0.5026835459884529, 0.5019684454357245, 0.5012755764634285, 0.5006040523536716, 0.4999530312994037, 0.499321713608716, 0.49870933911464793, 0.49811518477330174, 0.4975385624346057, 0.49697881677157707, 0.4964353233551691, 0.4959074868629958, 0.49539473941129253, 0.4948965390003227, 0.49441236806446714, 0.49394173211882636, 0.4934841584949686, 0.4930391951591029, 0.49260640960643975, 0.4921853878261086, 0.4917757333314335, 0.49137706625081085, 0.490989022474798, 0.49061125285541984, 0.49024342245397357, 0.48988520983395206, 0.4895363063959379, 0.4891964157515924, 0.4888652531340674, 0.48854254484237375, 0.48822802771748425, 0.4879214486479829, 0.4876225641034117, 0.4873311396934497, 0.48704694975130125, 0.4867697769397077, 0.48649941187820156, 0.48623565279022984, 0.48597830516892665, 0.4857271814604015, 0.4854821007634394, 0.48524288854467146, 0.48500937636823244]

# %%
# creating our predictions, our threshold should be 0.5


def predictions(final_w, final_b, X, sig):
    
    m = X.shape[0]
    predics = np.zeros(m)
    
    for i in range(m):
        calc = np.dot(X[i], final_w) + final_b
        apply_sig = sig(calc)
        if (apply_sig >= 0.5):
            predics[i] = 1
        else:
            predics[i] = 0

    return predics

# %% [markdown]
# # Logistic Regression model performance against scikit model
#
#
# #### General Observations
#
# We can see that there is high bias and the model seems to be relatively underfitting. It seems to also pertain a high level of variance as the model doesn't seem to generalize well to unseen data. It seems that a different algorithm is required. Down below, we will also implement the KNN model.
#
# ### Our model
#
# #### Jtrain = 77.2% accuracy
# #### Jtest = 75% accuracy
#
# ### Scikit Learn model
#
# #### Jtrain = 77.8% accuracy

# %%
# our accuracy

prediction = predictions(final_w, final_b, X_train_standardized, sigmoid)
print(prediction.shape)


print('Train Accuracy: %f'%(np.mean(prediction == y_train) * 100))
# Out:
# (2076,)
# Train Accuracy: 77.263969

# %%
# improving performance?

from sklearn.linear_model import LogisticRegression

logisticRegr = LogisticRegression()
logisticRegr.fit(X_train_standardized, y_train)

predictions = logisticRegr.predict(X_train_standardized)


print('Train Accuracy: %f'%(np.mean(predictions == y_train) * 100))


#X_test = X_test.to_numpy()
#y_test = y_test.to_numpy()


#X_test_standardized = scaler.fit_transform(X_test)

#predictions1 = logisticRegr.predict(X_test_standardized)


#print('Train Accuracy: %f'%(np.mean(predictions1 == y_test) * 100))
# Out:
# Train Accuracy: 77.842004
# Train Accuracy: 76.589595

# %%
#test data

X_test_standardized = scaler.fit_transform(X_test)

print(X_test_standardized.shape)
print(X_train_standardized.shape)
#prediction1 = predictions(final_w, final_b, X_test_standardized)
#print(prediction1.shape)


#print('Train Accuracy: %f'%(np.mean(prediction1 == y_test) * 100))


#print(sigmoid(0))


print(X_test_standardized[0])
su = np.dot(final_w, X_test_standardized[0]) + final_b
print(sigmoid(su))
print(y_test[0])
# Out:
# (692, 8)
# (2076, 8)
# [-0.55974331 -0.91110142 -0.81133488 -1.34423814 -0.73892647 -0.23567484
#  -1.05181983 -0.95135296]
# 0.11211408830895252
# 0

# %%
# other visualizations (plotting decision boundary?)


def predictions1(final_w, final_b, X, sig):
    
    m = X.shape[0]
    predics = np.zeros(m)
    
    for i in range(m):
        calc = np.dot(X[i], final_w) + final_b
        apply_sig = sig(calc)
        if (apply_sig >= 0.5):
            predics[i] = 1
        else:
            predics[i] = 0

    return predics

# %%
# our analysis, conclusions, and deployment?

prediction1 = predictions1(final_w, final_b, X_test_standardized, sigmoid)

print('Train Accuracy: %f'%(np.mean(prediction1 == y_test) * 100))
# Out:
# Train Accuracy: 75.578035

# %% [markdown]
# # Implementing KNN model from scratch

# %% [markdown]
# #### We will first calculate the euclidean distance between two vectors. It is also known as the L2 norm due to the p value in minoskwi formula distance

# %%
x1 = np.array([1, 2, 3, 4])
x2 = np.array([3, 3, 5, 6])

math.sqrt(np.sum((x1-x2)**2))
# Out:
# 3.605551275463989

# %% [markdown]
# ### Euclidean Distance function

# %%
def euclidean_distance(x1, x2):
    distance = np.sum((x1-x2)**2)
    distance = math.sqrt(distance)
    
    return distance

# %%
scaler = StandardScaler()
X_train_standardized = scaler.fit_transform(X_train)
X_test_standardized = scaler.fit_transform(X_test)

# %%
def knn_fit(x, x_rest, y_rest, dis_funct, k):
    
    distances = {}
    m = x_rest.shape[0]
    for i in range(m): 
        dist = dis_funct(x, x_rest[i])
        distances[i] = dist
    # sort distances from biggest to least (how many depends on the number of neighbors)
    distances = OrderedDict(sorted(distances.items(), key=lambda x:x[1])[:k])
    
    # majority class label? (how to retrieve y) ()
    categories = [y_rest[key] for key in distances] # retreiving the outcome for those distances
    
    cats = Counter(categories)
    
    return cats.most_common(1)[0][0]

# %%
predictions2 = []



for x in X_test_standardized:
    output = knn_fit(x, X_train_standardized, y_train, euclidean_distance, 3)
    predictions2.append(output)



#print('Train Accuracy: %f'%(np.mean(predictions == y_train) * 100))

# %%
print('Test Accuracy: %f'%(np.mean(predictions2 == y_test) * 100))
# Out:
# Test Accuracy: 92.919075

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3)
classifier.fit(X_train_standardized, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = classifier.predict(X_test_standardized)

# %%
print('Train Accuracy: %f'%(np.mean(y_pred == y_test) * 100))
# Out:
# Train Accuracy: 92.919075

# %% [markdown]
# ### Manhattan Distance
#
# Manhattan distance works better with more dimensions than euclidean distance since it is not as sensitive to outliers

# %%
def manhattan_distance(x1, x2):
    distance = np.sum(np.absolute(x1-x2))
    return distance

# %%
predictions3 = []



for x in X_test_standardized:
    output = knn_fit(x, X_train_standardized, y_train, manhattan_distance, 3)
    predictions3.append(output)

# %%
print('Test Accuracy: %f'%(np.mean(predictions3 == y_test) * 100))
# Out:
# Test Accuracy: 92.485549

# %% [markdown]
# # Evaluation metrics

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import recall_score

# %%
cm2 = confusion_matrix(y_test, predictions3)

# %%
display = ConfusionMatrixDisplay(cm2)
display.plot()

# %%
recall = 193/(193 + 29)*100
print(recall)
# Out:
# 86.93693693693693

# %%
recall_score(y_test, predictions3)
# Out:
# 0.8693693693693694
