# %%
import numpy as np
import matplotlib.pyplot as plt
from kmeans import KMeans

# %%
original_img = plt.imread('bird_small.png')

# %%
# visualizing original image


plt.imshow(original_img) # original image

# %%
# What are it's dimensions

original_img.shape
# Out:
# (128, 128, 3)

# %%
# For visualizing the colors

# this gives the RGB which have three values (R, G, B) each ranging from 0-255
# intensity. Here we plot the colors to visualize the shape

rgb_values = original_img[50, 33, :] 
                                     

# Create a 1x1 grid plot
fig, ax = plt.subplots(1, 1, figsize=(3, 3))

# Display the color using a patch
ax.add_patch(plt.Rectangle((0, 0), 1, 1, color=rgb_values))
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
X_img = np.reshape(original_img, (original_img.shape[0] * original_img.shape[1], 3))

# %%
X_img[0]
# Out:
# array([0.85882354, 0.7058824 , 0.40392157], dtype=float32)

# %%
K = 16
lowest_cost = float('inf')
lowest_cost_centroids = None
lowest_cost_idx = None

for i in range(100):
    km1 = KMeans(10, clusters=K)
    centroids, idx, total_cost = km1.fit(X_img)
    if total_cost < lowest_cost:
        lowest_cost_centroids = centroids
        lowest_cost_idx = idx
        lowest_cost = total_cost
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 8
#       6 for i in range(100):
#       7     km1 = KMeans(10, clusters=K)
# ----> 8     centroids, idx, total_cost = km1.fit(X_img)
#       9     if total_cost < lowest_cost:
#      10         lowest_cost_centroids = centroids
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
    







km2 = KMeans(10, clusters=K1)

# %%
#centroids, idx = km1.fit(X_img)

# %%
centroids1, idx1, costs = km2.fit(X_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 centroids1, idx1, costs = km2.fit(X_img)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
X_recovered = centroids[idx, :] 


# Reshape image into proper dimensions
X_recovered = np.reshape(X_recovered, original_img.shape)

# %%
X_1 = centroids1[idx1, :]
X_1 = np.reshape(X_1, original_img.shape)

# %%
fig, ax = plt.subplots(1,3, figsize=(16,16))
plt.axis('off')

ax[0].imshow(original_img)
ax[0].set_title('Original')
ax[0].set_axis_off()


# Display compressed image
ax[1].imshow(X_recovered)
ax[1].set_title('Compressed with %d colours'%K)
ax[1].set_axis_off()


ax[2].imshow(X_1)
ax[2].set_title('Compressed with %d colours'%K1)
ax[2].set_axis_off()
